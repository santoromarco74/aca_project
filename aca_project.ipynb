# %% [markdown]
# <a href="https://colab.research.google.com/github/santoromarco74/aca_project/blob/main/aca_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Aug 11 17:05:08 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !gcc -O2 -Wall -c drive/MyDrive/ACA_proj/cxf_loader.c -o drive/MyDrive/ACA_proj/cxf_loader.o
# !gcc -O2 -Wall -o drive/MyDrive/ACA_proj/centroid_serial drive/MyDrive/ACA_proj/centroid_serial.c drive/MyDrive/ACA_proj/cxf_loader.o
# !gcc -O2 -Wall -o drive/MyDrive/ACA_proj/compare_outputs drive/MyDrive/ACA_proj/compare_outputs.c -lm

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0

# %%
# !cd drive/MyDrive/ACA_proj/

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !nvcc -O2 -o drive/MyDrive/ACA_proj/centroid_cuda drive/MyDrive/ACA_proj/centroid_cuda.cu drive/MyDrive/ACA_proj/cxf_loader.c
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !./drive/MyDrive/ACA_proj/centroid_serial drive/MyDrive/ACA_proj/L675_004900.cxf
# Out:
# Caricate 625 particelle, 8918 vertici, da drive/MyDrive/ACA_proj/L675_004900.cxf
# Tempo calcolo (solo loop centroidi): 0.0567 ms
# Risultati scritti in centroids_serial.csv

# %%
# !./drive/MyDrive/ACA_proj/centroid_cuda drive/MyDrive/ACA_proj/L675_004900.cxf
# Out:
# Caricate 625 particelle, 8918 vertici, da drive/MyDrive/ACA_proj/L675_004900.cxf
# Tempo copia host->device: 0.5793 ms
# Tempo kernel:             174.1581 ms
# Tempo copia device->host: 0.0500 ms
# Tempo totale GPU:         174.7874 ms
# (grid = 157 blocchi x 128 thread, 625 warp totali per 625 regioni)
# Risultati scritti in centroids_cuda.csv
